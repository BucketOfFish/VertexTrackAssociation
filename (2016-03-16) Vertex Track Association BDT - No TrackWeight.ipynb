# %% [markdown]
# Using Athena version 20.7.3.8, on /afs/cern.ch/user/m/mazhang/eos/atlas/user/m/mazhang/Data/xAOD/VertexingXAODttbar/XAOD.pileupTruth.ttbar.pool.root.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
data = np.loadtxt("Data/TrackAssociation/mergedTrackAssociation.txt", delimiter="\t")

# %%
X = np.delete(data, -1, 1) #delete isCorrectVtx branch
X = np.delete(X, 6, 1) #delete truVtxX branch
X = np.delete(X, 6, 1) #delete truVtxY branch
X = np.delete(X, 6, 1) #delete truVtxZ branch
X = np.delete(X, -1, 1) #delete trkWeight branch
y = np.array([row[-1] for row in data])

# %%
branch_names = "d0, z0, phi, eta, qOverP, pT".split(",")
branch_names = [c.strip() for c in branch_names]

# %%
from sklearn.cross_validation import train_test_split

X_dev, X_eval, y_dev, y_eval = train_test_split(X, y, test_size=0.33, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_dev, y_dev, test_size=0.33, random_state=492)

# %%
signal = y_train==1
background = y_train==0

print(sum(signal))
print(sum(background))

plt.hist(X_train[signal,6], facecolor='red', alpha=0.5)
plt.xlabel(branch_names[6])
plt.show()
plt.hist(X_train[background,6], facecolor='blue', alpha=0.5)
plt.xlabel(branch_names[6])
plt.show()
# Out:
# 63457
# 7148

# %%
plt.scatter(X_train[signal,0], X_train[signal,1], c='red', alpha=0.5)
plt.scatter(X_train[background,0], X_train[background,1], c='blue', alpha=0.5)
plt.xlabel(branch_names[0])
plt.ylabel(branch_names[1])
plt.show()

plt.scatter(X_train[signal,0], X_train[signal,1], c='red', alpha=0.5)
plt.xlabel(branch_names[0])
plt.ylabel(branch_names[1])
plt.show()

plt.scatter(X_train[background,0], X_train[background,1], c='blue', alpha=0.5)
plt.xlabel(branch_names[0])
plt.ylabel(branch_names[1])
plt.show()

# %%
signal = y_train==1
background = y_train==0

plt.hist(X_train[signal,3], facecolor='red', alpha=0.5)
plt.xlabel(branch_names[3])
plt.show()
plt.hist(X_train[background,3], facecolor='blue', alpha=0.5)
plt.xlabel(branch_names[3])
plt.show()

# %%
plt.scatter(X_train[signal,4], X_train[signal,5], c='red', alpha=0.5)
plt.scatter(X_train[background,4], X_train[background,5], c='blue', alpha=0.5)
plt.xlabel(branch_names[4])
plt.ylabel(branch_names[5])
plt.show()

plt.scatter(X_train[signal,4], X_train[signal,5], c='red', alpha=0.5)
plt.xlabel(branch_names[4])
plt.ylabel(branch_names[5])
plt.show()

plt.scatter(X_train[background,4], X_train[background,5], c='blue', alpha=0.5)
plt.xlabel(branch_names[4])
plt.ylabel(branch_names[5])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, roc_auc_score

dt = DecisionTreeClassifier(max_depth=3,
                            min_samples_leaf=0.05*len(X_train))
bdt = AdaBoostClassifier(dt,
                         algorithm='SAMME',
                         n_estimators=800,
                         learning_rate=0.5)

bdt.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_samples_leaf=3530.25, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=0.5, n_estimators=800, random_state=None)

# %%
y_predicted = bdt.predict(X_test)
print (classification_report(y_test, y_predicted, target_names=["false trk/vtx match", "true trk/vtx match"]))
print ("Area under ROC curve: %.4f"%(roc_auc_score(y_test, bdt.decision_function(X_test))))
# Out:
#                      precision    recall  f1-score   support
#
# false trk/vtx match       0.44      0.03      0.05      3624
#  true trk/vtx match       0.90      1.00      0.94     31153
#
#         avg / total       0.85      0.89      0.85     34777
#
# Area under ROC curve: 0.7334

# %%
from sklearn.metrics import roc_curve, auc

decisions = bdt.decision_function(X_test)
# Compute ROC curve and area under the curve
fpr, tpr, thresholds = roc_curve(y_test, decisions)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, lw=1, label='ROC (area = %0.2f)'%(roc_auc))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
def compare_train_test(clf, X_train, y_train, X_test, y_test, bins=30):
    decisions = []
    for X,y in ((X_train, y_train), (X_test, y_test)):
        d1 = clf.decision_function(X[y>0.5]).ravel()
        d2 = clf.decision_function(X[y<0.5]).ravel()
        decisions += [d1, d2]
        
    low = min(np.min(d) for d in decisions)
    high = max(np.max(d) for d in decisions)
    low_high = (low,high)
    
    plt.hist(decisions[0], color='r', alpha=0.5, range=low_high, bins=bins, histtype='stepfilled', normed=True, label='S (train)')
    plt.hist(decisions[1], color='b', alpha=0.5, range=low_high, bins=bins, histtype='stepfilled', normed=True, label='B (train)')

    hist, bins = np.histogram(decisions[2], bins=bins, range=low_high, normed=True)
    scale = len(decisions[2]) / sum(hist)
    err = np.sqrt(hist * scale) / scale
    
    width = (bins[1] - bins[0])
    center = (bins[:-1] + bins[1:]) / 2
    plt.errorbar(center, hist, yerr=err, fmt='o', c='r', label='S (test)')
    
    hist, bins = np.histogram(decisions[3], bins=bins, range=low_high, normed=True)
    scale = len(decisions[2]) / sum(hist)
    err = np.sqrt(hist * scale) / scale

    plt.errorbar(center, hist, yerr=err, fmt='o', c='b', label='B (test)')

    plt.xlabel("BDT output")
    plt.ylabel("Arbitrary units")
    plt.legend(loc='best')
    
compare_train_test(bdt, X_train, y_train, X_test, y_test)
