# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
efficiency_BDT = [0.95287465, 0.96634256, 0.97474747, 0.98236237, 0.98979013, 0.9884106, 0.98287064, 0.9835966, 0.96748555, 0.94732062];
mismatch_BDT = [0.20535012, 0.10215427, 0.08579882, 0.0622449, 0.06634564, 0.06569343, 0.07555556, 0.0831448, 0.11456954, 0.18530102];
efficiency_NN = [0.99905749, 0.99700823, 0.99621212, 0.99465526, 0.9960295, 0.99337748, 0.99350266, 0.99696233, 0.99710983, 0.99636694];
mismatch_NN = [0.23758099, 0.13553826, 0.11142375, 0.07412935, 0.07432789, 0.07212777, 0.09228278, 0.11285097, 0.1450713, 0.24482759];
efficiency_SVM = [0.98397738, 0.98279731, 0.98358586, 0.97594869, 0.97958026, 0.98675497, 0.98168931, 0.9835966, 0.97615607, 0.98546776];
mismatch_SVM = [0.22740741, 0.11981258, 0.10201729, 0.06598465, 0.06648649, 0.06089239, 0.07973422, 0.09340045, 0.12677878, 0.21861472];

# %%
plt.plot(efficiency_BDT)
plt.plot(efficiency_NN)
plt.plot(efficiency_SVM)
plt.show()

plt.plot(mismatch_BDT)
plt.plot(mismatch_NN)
plt.plot(mismatch_SVM)
plt.show()
